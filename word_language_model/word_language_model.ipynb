# %%
import torch
import json
import torch.nn as nn
import numpy as np

from random import randrange

EMBEDDING_FILE = 'glove.840B.300d.txt'
EMBEDDING_DIM = 64

class WordLanguageModel(nn.Module):
    def __init__(self, num_unique_words, hidden_state_dim=512):
        super(WordLanguageModel, self).__init__()
        self.embeddings = nn.Embedding(num_unique_words, EMBEDDING_DIM)
                            
        self.lstm = nn.LSTM(input_size=EMBEDDING_DIM, hidden_size=hidden_state_dim, num_layers=3)

        self.linear_layer_1 = nn.Linear(hidden_state_dim, 64)
        self.linear_layer_2 = nn.Linear(64, num_unique_words)

        self.relu = nn.LeakyReLU()

    
    def forward(self, word_indices_tensor):
        out = self.embeddings(word_indices_tensor)

        out, h = self.lstm(out)
        
        out = self.linear_layer_1(out)
        out = self.relu(out)
        
        out = self.linear_layer_2(out)
        return out
    
class WordLanguageModelWrapper:
    def __init__(self, context_window=300, hidden_state_dim=512):
        self.context_window = context_window
        self.hidden_state_dim = hidden_state_dim
        
    def load_data(self, file_path):
        with open(file_path, 'r') as file:
            self.training_data = [v for v in file.read().replace('.', ' .').replace(',', ' ,').replace('!', ' !').replace('?', ' ?').replace(':', ' :').replace(';', ' ;').replace("'", " ' ").replace("(", " ) ").replace("-", " - ").split() if v != '']
        
        print('Num Words training data', len(self.training_data))
        
    def load_word_embeddings(self):
        self.embeddings_dict = {}
        with open(EMBEDDING_FILE, 'r') as f:
            for line in f:
                values = line.split()
                word = values[0]
                try:
                    vector = np.asarray(values[1:], "float32")
                    self.embeddings_dict[word] = vector
                except:
                    pass

    def load_unique_words(self, min_word_count=0): 
        word_counts = {}
        for w in self.training_data:
            if w not in word_counts:
                word_counts[w] = 0
            word_counts[w] += 1
        
        self.unique_words = {w: i for i, w in enumerate([w for w, count in word_counts.items() if count > min_word_count])}
        self.num_unique_words = len(self.unique_words) + 1
        print('Num Words:', self.num_unique_words)

    def create_model(self):
        has_cuda = torch.cuda.is_available()
        print('Has CUDA', has_cuda)
        self.device = torch.device('cuda' if has_cuda else 'cpu')
        self.model = WordLanguageModel(self.num_unique_words, self.hidden_state_dim).to(self.device)
    
    def train_model(self, epochs=1, lr=0.0001, skip_factor=1):
        optimizer = torch.optim.Adam(self.model.parameters(), lr=lr)
        
        for epoch in range(epochs):
            offset = randrange(self.context_window * skip_factor)
            total_loss = 0

            while offset + self.context_window + 1 < len(self.training_data):
                optimizer.zero_grad()
                
                text_in = self.training_data[offset:offset + self.context_window + 1]
                #print(text_in)
                #text_in_tensor = self._text_to_embedding_tensor(text_in)
                text_out_tensor = self._text_to_index_tensor(text_in)
                prediction = self.model.forward(torch.LongTensor(np.array(text_out_tensor[:-1])).to(self.device))
                loss = nn.functional.cross_entropy(prediction, torch.LongTensor(text_out_tensor[1:]).to(self.device))
                loss.backward()
                optimizer.step()

                total_loss += loss.item()
            
                offset += self.context_window * skip_factor
            print(f'Epoch {epoch + 1}, Train Loss {total_loss}')
    
    def predict(self, text, length=200):
        for i in range(length):
            text_in_tensor = self._text_to_index_tensor(text)
            prediction = self.model.forward(torch.LongTensor(text_in_tensor).to(self.device))
            
            probs = nn.functional.softmax(prediction[-1], dim=0).detach().cpu().numpy()
            res_index = np.random.choice(range(len(probs) - 1), p=probs[:-1]/sum(probs[:-1]))
            res_word = list(self.unique_words.keys())[res_index]
            
            text.append(res_word)
        
        return text
    
    def store_model(self, name):
        torch.save(self.model.state_dict(), f'models/{name}.pt')
        
        with open(f'models/{name}.json', 'w') as f:
            json.dump({'unique_words': self.unique_words, 'num_unique_words': self.num_unique_words}, f)
    
    def load_model(self, name):
        with open(f'models/{name}.json') as f:
            d = json.load(f)
            self.unique_words = d['unique_words']
            self.num_unique_words = d['num_unique_words']
        
        self.create_model()

        self.model.load_state_dict(torch.load(f'models/{name}.pt'))
        self.model.eval()
    
    def _text_to_embedding_tensor(self, text_in):
        return [self._get_word_embedding(word) for word in text_in]
    
    def _text_to_index_tensor(self, text_in):
        text_in_tensor = []
        for word in text_in:
            text_in_tensor.append(self._get_word_index(word))
        return text_in_tensor
    
    def _get_word_embedding(self, word):
        if word in self.embeddings_dict and word != '<unk>':
            return self.embeddings_dict[word]
        else:
            return np.zeros(EMBEDDING_DIM)
        
    def _get_word_index(self, word):
        return self.unique_words[word] if word in self.unique_words else self.num_unique_words - 1

# %%
# Model training
def train():
    model = WordLanguageModelWrapper(hidden_state_dim=512)
    #model.load_word_embeddings()
    #model.load_data('wiki.train.tokens')
    model.load_data('1984.txt')
    model.load_unique_words()
    model.create_model()

    for i in range(100000):
        model.train_model(epochs=10)
        print(model.predict(['None']))

        if i % 10 == 0:
            model.store_model(f'epoch_{i + 1}')
train()
# Out:
# Num Words training data 124260
# Num Words: 9769
# Has CUDA True
# Epoch 1, Train Loss 3071.3514699935913
# Epoch 2, Train Loss 2685.243432998657
# Epoch 3, Train Loss 2664.2964062690735
# Epoch 4, Train Loss 2649.4608402252197
# Epoch 5, Train Loss 2646.533802509308
# Epoch 6, Train Loss 2644.2896852493286
# Epoch 7, Train Loss 2643.7853541374207
# Epoch 8, Train Loss 2643.2550024986267
# Epoch 9, Train Loss 2642.8167390823364
# Epoch 10, Train Loss 2642.0050134658813
# ['None', 'dead', 'have', 'O', ',', 'Hundreds', "'", 'up', 'know', 'looked', 'lump', 'of', 'sitting', ',', 'If', 'one', 'A', 'it', 'of', ',', 'powerful', 'her', 'said', 'six', 'aeroplane', '.', 'it', ',', ',', 'questions', 'renting', 'that', 'need', ',', 'came', ',"', 'the', 'saucepan', 'the', 'said', 'some', 'the', 'only', '.', 'physical', 'But', 'the', 'dare', ',', ',', 'and', 'I', ',', 'astronomy', 'had', 'treachery', 'to', 'still', 'might', 'In', 'suddenly', 'estimates', ',', 'die', 'to', 'huge', 'with', 'at', 'right', 'When', 'earth', 'pacing', 'times', 'reality', ',', 'only', 'Winston', '.', 'at', 'out', 'less', 'led', 'We', 'be', 'his', 'a', 'The', 'a', 'that', 'platform', '-', 'medley', 'crime', 'The', 'fallen', 'They', 'into', 'to', 'alive', ',', 'He', 'indeed', 'water', 'exactly', 'like', 'was', 'starts', ',', 'because', '.', 'square', 'to', 'By', 'unorthodoxy', 'But', 'too', 'of', 'lies', 'the', 'way', 'dare', 'idea', 'overthrown', ',', 'maintains', 'you', 'crimes', '.', 'than', 'it', 'years', 'Party', 'on', 'thinking', 'of', ',', ',', 'touching', 'wrung', 'which', "'", 'to', 'you', 'stood', 'The', 'of', 'streamers', 'said', 'began', '.', 'to', 'coloured', 'in', 'took', 'to', 'paid', '.', 'lived', '.', 'once', 'lie', 'sat', 'passage', 'a', 'have', 'unmistakable', ',', ',', 'the', 'dirty', 'bondage', 'like', ',', 'Winston', 'I', 'not', 'aged', 'a', 'they', 'stand', 'always', 'had', 'over', 'and', 'for', 'from', 'terms', 'eyes', 'or', '-', 'place', 'fitting', 'metal', 'different', 'of', 'bound', 'like', 'already', 'Sir', ',', 'hand']
# Epoch 1, Train Loss 2666.499517440796
# Epoch 2, Train Loss 2652.476836204529
# Epoch 3, Train Loss 2643.0112810134888
# Epoch 4, Train Loss 2649.2086896896362
# Epoch 5, Train Loss 2640.8506274223328
# Epoch 6, Train Loss 2639.812774181366
# Epoch 7, Train Loss 2639.083861351013
# Epoch 8, Train Loss 2638.7443075180054
# Epoch 9, Train Loss 2645.9721517562866
# Epoch 10, Train Loss 2637.8334488868713
# ['None', 'the', 'was', 'darkening', 'arm', 'fought', 'a', 'him', 'in', 'Its', 'your', ',', 'speaking', 'the', 'Thought', 'anyone', 'unrepented', 'It', 'hopeless', 'shall', 'for', 'by', 'said', ',', 'O', 'deep', 'What', 'seldom', 'rewrite', 'small', 'she', 'voluntary', 'very', 'us', 'dome', 'stood', 'side', 'virtue', 'I', '.', 'liberated', 'rapidly', 'He', 'banners', 'apologetically', 'fraction', 'waiter', 'was', 'began', 'was', ',', ',', 'you', 'power', 'middle', 'meaning', 'the', 'of', 'stopped', 'plumped', ',', 'beautiful', 'organization', 'and', 'entailed', 'were', 'He', ':', 'of', 'rubbishy', 'dozen', 'in', 'chanted', 'of', '-', 'might', 'after', 'skull', 'O', 'in', 'the', 'apart', 'his', 'To', 'the', 'brought', ',', 'mouth', 'giving', 'keep', 'had', 'of', 'by', 'not', 'Do', 'He', ',', 'certainty', ')', 'exist', 'future', 'You', 'he', 'of', 'mental', 'floor', 'take', 'sat', 'bad', ',', 'century', 'The', 'had', 'throats', 'to', 'Here', 'girl', 'Australia', 'of', '-', 'nominate', 'exercise', 'war', 'great', 'neighbours', 'new', 'There', ',', 'minutes', 'Brother', 'shove', 'just', 'He', 'old', 'unconsciousness', 'no', 'that', 'were', "'", 'by', 'smallest', 'same', 'mysteriously', 'a', 'of', 'of', 'like', 'should', 'it', 'Even', 'the', 'door', ',', 'could', 'broad', 'very', ',', 'century', '!', 's', 'cry', 'cut', 'but', 'pleasure', 'exactly', 'map', 'called', 'he', 'activities', 'smuggled', 'undifferentiated', 'a', 'him', 'years', '1973', 'THE', 'without', 'shock', 'moved', 'could', 'prisoners', 'Thass', 'the', '-', 'blunt', 'cattle', 'black', ',', 'of', 'spans', 'seconds', 'the', 'literature', 'and', 'pen', 'will', 'repainted', 'floor', '.', 'better', 'on']
# Epoch 1, Train Loss 2659.6798515319824
# Epoch 2, Train Loss 2643.6936292648315
# Epoch 3, Train Loss 2646.8700857162476
# Epoch 4, Train Loss 2612.862956047058
# Epoch 5, Train Loss 2602.955690383911
# Epoch 6, Train Loss 2594.1709065437317
# Epoch 7, Train Loss 2583.8074440956116
# Epoch 8, Train Loss 2571.2216606140137
# Epoch 9, Train Loss 2550.7110290527344
# Epoch 10, Train Loss 2525.878499031067
# ['None', 'soft', 'in', 'trying', 'had', 'cropped', 'ineffectual', 'in', 'broken', 'concrete', 'hopefully', ',', 'was', 'his', 'atmosphere', 'BIG', 'squeeze', 'will', 'again', 'not', 'incautiously', 'shutting', 'another', 'from', 'almost', 'was', 'explosion', 'easily', 'of', 'but', 'had', 'want', ',', "'", 'bother', 'happened', '.', 'The', 'morality', 'of', 'in', 'their', 'are', 'gramophone', 'hands', 'it', 'to', 'undesirable', 'marriages', 'off', '.', 'barely', '.', 'matter', "'", 'few', 'quickly', ',', 'necessary', 'of', 'a', 'facing', 'everything', 'seem', 'history', ',', '.', "'", 'from', 'turned', 'always', 'little', 'have', 'voice', 'it', 'was', ',', 'advance', 'were', 'across', ',', 'for', 'Aaronson', 'even', 'his', 'before', 'of', 'A', 'thousand', '.', 'The', 'after', 'except', 'had', ',', 'was', 'again', 'destroyed', 'it', 'itself', '.', 'ordinary', 'preparing', 'in', 'his', "'", 'the', 's', 'head', '-', 'embodied', 'on', 'have', 'touch', 'it', ',', 'the', 'have', 'had', 'necessary', 'of', 'might', ',', 'raised', ',', 'peoples', ',', 'had', 'heels', '.', 'filled', 'they', 'had', 'pace', ',', 'criminal', 'voice', 'was', ',', 'sleepy', 'one', 'bathroom', ',', 'the', 'end', 'should', ',', '.', 'not', 'How', 'messages', 'Julia', 'before', 'of', 'eye', ',', 'nakedness', 'SLAVERY', 'what', 'as', '.', 'better', ',', 'in', 'on', 'its', 'present', 'make', ',', 'did', 'even', 'whose', 'conquered', 'there', 'difficulty', 'in', "'", 'at', 'over', 'was', 'remembered', 'carelessly', 'is', 'in', 'it', 'from', 'from', 'was', 'happens', '?', 'the', 'loins', 'a', 'balance', 'but', 'will', 'indefinable', 'in', 'not', 'quickly', ',']
# Epoch 1, Train Loss 2510.5109457969666
# Epoch 2, Train Loss 2473.798442840576
# Epoch 3, Train Loss 2444.6026186943054
# Epoch 4, Train Loss 2416.728558063507
# Epoch 5, Train Loss 2390.014730453491
# Epoch 6, Train Loss 2363.2620301246643
# Epoch 7, Train Loss 2337.004605770111
# Epoch 8, Train Loss 2317.5817375183105
# Epoch 9, Train Loss 2293.3335933685303
# Epoch 10, Train Loss 2268.568953037262
# ['None', 'anyone', 'it', 'wind', 'greatly', ',', 'which', 'shall', 'it', 'was', 'against', 'that', ',', 'years', 'give', ',', 'DUCKSPEAK', 'besides', 'to', 'the', 'sort', '.', 'rhythmic', 'had', 'that', ',', 'in', 'spoken', 'in', 'the', 'own', 'man', 'at', 'the', 'green', 'with', 'easily', 'ideas', 'that', 'some', 'also', 'a', 'stared', 'of', 'hide', 'etc', ',', 'been', 'truncheons', 'was', 'surprised', 'which', 'because', 'was', 'the', 'unusual', 'from', 'the', 'pieces', '.', 'He', 'was', 'by', 'the', 'violent', 'bleating', 'inherent', 'with', 'attitude', 'walked', 'rabbits', 'demanded', 'the', 'soft', 'still', '.', 'But', 'Syme', 'he', 'is', 'been', 'your', 'speech', ',', 'covering', ',', 'he', 'parts', 'that', 'he', 'when', 'it', 'explained', 'aware', 'on', 'her', 'him', ',', 'later', 'hemmed', 'of', 'no', 'Relative', 'of', 'i', 'it', 'the', 'frequenting', ',', 'arriving', 'it', 'quickly', 'into', 'the', 'TOUR', 'start', '?', 'It', 'was', 'longer', 'had', 'caught', 'back', 'of', 'nineteenth', 'that', 'it', 'he', 'had', 'prevaricate', 'that', "'", 'Brien', 'Syme', 'you', 'a', 'Oceanic', 'arguments', 'and', 'often', 'no', 'consider', ',', 'it', 'you', 'all', 'her', 'the', 'past', 'Parsons', 'is', 'wide', ',', 'they', 'was', 'Newspeak', 'while', ',', 'about', 'rapidly', 'avoid', 'immediately', '.', 'The', 'few', 'only', 'that', 'generalized', 'up', 'to', 'impossible', 'on', 'millions', 'metres', ',', 'hand', '.', 'There', 'is', 'the', 'organism', 'May', 'burst', ';', 'demanded', 'Party', ',', 'and', 'that', 'was', 'wave', 'looking', 'tomorrow', 'the', 'caption', 'figures', 'of', 'but', 'appearance', 'to', 'whom']
# Epoch 1, Train Loss 2262.400188446045
# Epoch 2, Train Loss 2223.716094970703
# Epoch 3, Train Loss 2206.4657797813416
# Epoch 4, Train Loss 2177.5592908859253
# Epoch 5, Train Loss 2155.547784805298
# Epoch 6, Train Loss 2132.423101902008
# Epoch 7, Train Loss 2110.318793773651
# Epoch 8, Train Loss 2088.1947255134583
# Epoch 9, Train Loss 2065.990532398224
# Epoch 10, Train Loss 2044.83842420578
# ['None', ':', 'the', 'vile', 'thing', 'when', 'as', 'pressed', 'in', 'a', 'Science', 'was', 'perched', 'was', 'than', 'and', 'that', "'", 's', 'act', 'that', 'silenced', 'in', 'the', 'economy', 'of', 'Big', 'face', '.', 'Even', 'it', 'was', 'them', 'to', 'trampling', 'with', 'his', 'response', 'in', 'himself', '.', 'You', "'", 'reclaim', '-', '-', 'ONE', "'", 'O', "'", 'Brien', 'it', 'was', 'to', 'be', 'grandfather', 'outside', ',', 'there', 'was', 'a', 'interest', 'WE', 'in', 'or', 'people', '.', 'Room', '-', '-', 'will', 'Winston', 'went', 'it', 'was', 'worked', 'for', 'you', 'and', 'TREE', 'and', 'crushed', ',', 'which', 'in', 'just', 'cent', 'thirty', 'except', 'attack', 'ever', 'an', 'triumphant', 'doctrines', 'diseases', ',', 'sold', 'mentioned', 'roamed', 'thick', 'of', 'some', 'world', '.', 'B', 'Martin', 'he', 'knew', 'fit', 'as', 'themselves', 'he', 'was', 'and', 'words', 'and', 'OXES', 'frontier', 'letters', 'had', 'course', 'to', 'adding', 'in', 'a', 'instinct', 'by', 'the', 'slate', 'upon', 'and', 'victory', ',', 'or', 'a', 'power', '-', 'hatred', ',', 'full', 'simple', 'squeeze', '.', 'They', "'", 'By', 'face', 'of', 'part', 'knew', 'and', 'all', 'the', 'dial', 'as', 'a', 'description', ',', 'city', 'and', 'pay', 'a', 'glass', 'plaque', 'wars', 'while', ',', 'so', 'saved', ',', 'which', 'and', 'etymology', 'up', 'to', 'perhaps', 'for', 'CIGARETTES', 'and', 'adherents', 'the', 'face', 'Committee', '-', 'and', 'things', 'in', 'the', 'surroundings', 'of', 'grow', 'peculiar', 'RIGHTS', ',', 'wearing', 'grouping', ',', 'which', 'at', 'be', 'hardly']
# Epoch 1, Train Loss 2051.8532314300537
# Epoch 2, Train Loss 2020.0545892715454
# Epoch 3, Train Loss 1998.310260772705
# Epoch 4, Train Loss 1977.1816821098328
# Epoch 5, Train Loss 1955.3704006671906
# Epoch 6, Train Loss 1935.5262689590454
# Epoch 7, Train Loss 1924.5647213459015
# Epoch 8, Train Loss 1900.0952248573303
# Epoch 9, Train Loss 1884.5673186779022
# Epoch 10, Train Loss 1867.8292109966278
# ['None', 'mind', '.', 'Each', 'compared', 'in', 'the', 'true', 'word', 'in', 'the', 'smallest', 'subject', 'and', 'the', 'article', 'of', 'the', 'floor', '.', 'THINKPOL', 'clicked', 'glance', ',', 'the', 'language', 'of', 'triumph', 'on', 'memory', 'right', '.', 'His', 'section', 'where', 'life', 'again', '.', 'A', 'act', 'of', 'torture', 'was', 'the', 'table', '.', 'Syme', 'he', 'appeared', 'was', 'so', 'order', 'with', 'the', 'minimum', 'pocketed', 'age', 'to', 'English', '.', 'If', 'the', 'appearance', 'that', 'was', 'the', 'morning', ',', 'themselves', 'such', 'out', 'which', 'presented', 'entertainment', 'in', 'the', 'Party', 'that', 'saw', 'the', 'whole', 'between', ',', 'shedding', 'sole', 'to', 'communicate', 'now', 'and', 'there', 'was', 'fed', 'to', 'emptiness', 'words)', ',', 'and', 'being', 'the', 'fields', 'in', 'a', 'commandments', 'or', 'sitting', 'down', 'by', 'other', 'water', 'certain', 'whatever', 'at', 'a', 'frowsy', 'of', 'sanity', '.', 'You', 'contained', 'exposed', 'for', 'since', 'as', 'once', 'when', 'this', 'made', 'had', 'shrunk', 'up', 'to', 'vigour', 'sight', 'which', 'was', 'there', 'in', 'war', 'a', 'few', 'term', 'DUCKSPEAKER', '-', '-', 'emotion', 'of', 'equality', 'all', 'its', 'convenience', ',', 'straggled', '-', 'crowded', 'THESE', 'figure', 'of', 'words', 'when', 'vast', 'meanings', 'gasps', 'and', 'ten', 'cut', ',', 'but', 'example', 'all', 'thought', ',', 'in', 'SWAM', 'a', 'case', 'music', ',', 'securing', 'to', 'them', 'and', 'revolutionary', 'full', '.', 'Parsons', 'could', 'her', 'certain', 'false', 'a', 'immediate', 'of', 'the', 'hand', '.', 'In', 'a', 'single', ',', 'B', 'monologue']
# Epoch 1, Train Loss 1893.987067937851
# Epoch 2, Train Loss 1853.350149154663
# Epoch 3, Train Loss 1832.0368747711182
# Epoch 4, Train Loss 1819.0800306797028
# Epoch 5, Train Loss 1793.4392547607422
# Epoch 6, Train Loss 1774.1837446689606
# Epoch 7, Train Loss 1765.6595323085785
# Epoch 8, Train Loss 1748.2069292068481
# Epoch 9, Train Loss 1727.4148066043854
# Epoch 10, Train Loss 1715.6036779880524
# ['None', 'of', 'her', 'certainty', ',', 'grabbed', 'directly', '.', 'He', 'walked', 'to', 'besides', 'a', 'panegyric', 'lettering', 'through', 'the', 'uniform', 'in', 'hanging', '.', 'He', "'", 'turn', '!', 'Then', 'in', "'", 'O', "'", 'Brien', ',', 'Oceania', '.', 'One', 'could', 'noticed', 'that', 'though', 'remarkable', 'from', 'democracy', 'CERTAIN', 'killed', 'was', 'too', 'translation', ':', '-', 'blue', 'etc', 'is', 'not', 'transferred', 'of', 'self', '.', 'Thus', 'above', 'the', 'dirt', 'man', 'action', ',', 'respectively', ',', 'which', 'to', 'principle', 'in', 'HAPPINESS', 'words', 'and', 'love', 'up', 'to', 'senile', 'to', 'prepositional', 'as', 'than', 'you', ',', "'", 'his', 'next', 'place', '.', 'Check', '.', 'Two', 'expression', 'of', 'Oceania', 'there', 'were', 'killed', 'in', 'which', 'being', 'UNGOOD', 'for', 'doing', 'to', 'see', 'other', 'instrument', ',', 'the', 'words', 'was', 'all', 'as', 'suppressed', '.', 'Actually', 'what', ',', 'DOWN', ',', 'in', 'the', 'boy', ',', 'the', 'verb', ',', 'continuously', ',', 'the', 'WATCHING', 'that', 'some', 'gentle', 'scrutinized', 'in', 'the', 'diary', ',', 'adjective', ',', 'and', 'a', 'body', 'disgusting', '.', 'thought', ',', 'when', 'a', 'verb', 'of', 'mingled', 'co', ',', 'white', '-', '-', 'much', 'sided', 'discipline', '.', 'In', 'the', 'far', 'one', 'word', ',', 'in', 'the', 'side', 'were', 'gabbling', '.', 'It', 'was', 'setting', 'rapidly', 'in', 'a', 'sort', 'of', 'THINKPOL', 'piece', 'of', 'ideas', ',', 'government', ',', 'and', 'which', 'had', 'remained', 'talking', 'by', 'invent', 'flags', "'", 'the', 'Party', "'"]
# Epoch 1, Train Loss 1742.7805876731873
# Epoch 2, Train Loss 1720.940572977066
# Epoch 3, Train Loss 1696.1361997127533
# Epoch 4, Train Loss 1677.7299480438232
# Epoch 5, Train Loss 1660.7645766735077
# Epoch 6, Train Loss 1650.9775023460388
# Epoch 7, Train Loss 1635.3433060646057
# Epoch 8, Train Loss 1614.690681219101
# Epoch 9, Train Loss 1596.0010471343994
# Epoch 10, Train Loss 1590.158154964447
# ['None', 'when', 'he', 'reappeared', 'and', 'by', 'the', 'battlefield', 'muscles)', 'cardboard', '.', 'Every', 'head', 'was', 'its', 'full', 'face', '.', 'There', ',', 'with', 'their', 'sort', '-', 'obvious', 'system', 'and', 'falling', 'in', 'Newspeak', 'or', 'bringing', '.', 'Considerations', 'were', 'sitting', ',', 'when', 'the', 'telescreen', 'had', 'had', 'so', 'capable', 'as', 'a', 'chairs', 'chestnut', 'or', 'years', 'both', '.', 'The', 'B', 'vocabulary', 'had', 'spoken', 'in', 'a', 'few', 'beings', 'documents', ',', 'would', 'his', 'hands', '.', 'The', 'white', 'Police', 'unquestioning', 'in', 'the', 'moment', ',', 'pamphlets', 'again', ':', 'or', 'applied', 'happens', ',', 'WE', 'advocating', 'would', 'enthusiasm', 'wallowing', ',', 'errors', 'by', 'intelligence', 'complete', 'into', 'every', 'area', 'judgement', ',', 'on', 'such', 'or', 'deep', 'or', 'one', '.', 'In', 'him', 'through', 'the', 'number', 'that', 'were', 'thought', 'of', 'the', 'water', 'should', 'Syme', 'Powers', 'the', 'fear', 'of', 'special', '.net', '.', 'As', 'and', 'any', 'three', 'announcement', ',', 'nine', ',', '.', 'This', 'of', 'night', ',', 'or', 'MINILUV', 'of', 'all', 'rag', ',', 'watchful', 'laws', ',', 'of', 'their', 'face', 'boy', 'today', 'in', 'past', ',', 'and', 'THAT', 'pouched', 'of', 'behind', 'their', 'pipe', ',', 'which', 'made', 'called', 'Rutherford', 'to', 'the', 'tendency', 'of', 'children', '.', 'It', 'was', 'the', 'tail', 'way', ',', 'out', 'process', 'of', 'life', ',', 'OLDTHINK', '.', 'Greater', 'sink', 'her', ',', 'THE', 'cap', 'words', ',', 'irregular', ',', 'DESTRUCTIVE', ',', 'land', 'ill', ',', 'and']
# Epoch 1, Train Loss 1621.3041291236877
# Epoch 2, Train Loss 1579.8105599880219
# Epoch 3, Train Loss 1561.1338565349579
# Epoch 4, Train Loss 1538.2836277484894
# Epoch 5, Train Loss 1526.355674982071
# Epoch 6, Train Loss 1511.5858688354492
# Epoch 7, Train Loss 1495.4040524959564
# Epoch 8, Train Loss 1485.8973557949066
# Epoch 9, Train Loss 1468.6456644535065
# Epoch 10, Train Loss 1454.4174785614014
# ['None', 'of', 'civilization', 'such', 'frontier', 'drama', '!', 'Suddenly', 'eastward', 'by', 'adding', 'unless', 'along', 'long', 'methods', 'dented', '.]', 'verb', ';', 'THE', 'Chinese', 'which', 'made', 'ultimately', 'indoor', 'hopefully', 'together', 'and', 'SPEEDWISE', 'grounded', 'than', 'snooping', 'of', 'Oldspeak', ')', 'well', 'as', 'SEXCRIME', ',', 'quarto', 'BLACK', 'ENDS', 'JOYCAMP', 'involving', 'meant', 'by', 'choice', ',', 'THESE', ',', 'THESE', 'BECOMES', 'nobleman', 'George', 'tuft', 'THINKING', 'OF', 'decadence', 'POWERS', 'demanded', 'who', 'had', 'been', 'out', 'as', 'it', 'was', 'quite', 'meanings', 'fit', 'before', 'aint', 'now', 'up', "'", 'those', 'day', '!', "'", 'You', 'know', 'else', 'in', 'beauty', 'or', "'", 're', '6', 'could', 'become', 'seduced', ',', "'", "'", 'The', 'It', 'had', 'actually', ',', 'I', "'", 'said', 'the', 'window', '.', "'", 'You', 'quailed', "'", 'have', 'only', 'it', 'quietly', 'to', 'our', 'cold', 'cannot', 'ONE', '!', "'", 'Winston', 'had', 'made', 'seldom', 'occurring', 'at', 'brackets', 'minutes', '.', 'The', 'intellectual', 'Minutes', 'started', 'GOODTHINKFUL', 'flags', 'was', 'nebulous', 'called', 'methods', ',', 'and', 'it', 'was', 'to', 'think', 'a', 'folded', '.', 'He', 'found', ',', 'succeeded', 'out', 'except', 'under', 'express', 'speech', '.', 'Actually', 'to', 'be', 'boredom', 'for', 'age', 'putting', ',', 'although', 'was', 'were', 'inflected', '.', 'Examples', 'seemed', 'with', 'the', 'things', 'Withers', 'seized', 'known', 'controlled', 'by', 'waking', 'than', 'it', 'were', 'walking', '.', 'There', 'were', 'blue', 'face', 'also', 'mutilated', 'that', 'Newspeak', 'were', 'arms', ',', 'whereby', 'and', 'Greater']
# Epoch 1, Train Loss 1485.0854074954987
# Epoch 2, Train Loss 1447.311096906662
# Epoch 3, Train Loss 1430.8972041606903
# Epoch 4, Train Loss 1411.3271210193634
# Epoch 5, Train Loss 1395.8535199165344
# Epoch 6, Train Loss 1380.3773963451385
# Epoch 7, Train Loss 1362.3567247390747
# Epoch 8, Train Loss 1350.734045267105
# Epoch 9, Train Loss 1344.0842349529266
# Epoch 10, Train Loss 1321.0840611457825
# ['None', 'of', 'theory', ',', 'or', 'devices', 'more', 'and', 'office', 'to', 'preserve', 'with', 'overheard', 'to', 'its', 'ideological', 'aside', 'and', 'concrete', 'in', 'their', 'medicine', ',000', 'by', 'fornication', 'words', 'straggled', ',', 'and', 'almost', 'euphony', 'as', 'LIFE', 'together', 'on', 'well', 'political', 'out', 'of', 'such', 'meanings', 'in', 'their', 'roofs', 'level', '.', 'The', 'thing', 'was', 'a', 'species', 'OF', 'THAT', ')', 'as', 'instance', 'in', 'cabbage', 'to', 'be', 'intermittently', 'their', 'meanings', ';', 'involving', 'recognized', 'meditatively', 'an', 'tail', 'million', 'cent', 'as', 'THE', 'secondary', 'meanings', 'pig', 'or', 'chairs', 'Ogilvy', '.', 'generation', 'equality', 'demands', 'than', 'thought', 'appeared', 'yet', 'normal', 'by', 'fact', 'ARE', 'watchful', 'made', 'UNGOOD', 'meant', 'WITH', 'lost', 'orthodox', 'than', 'doing', 'by', 'adding', '?', 'THAT', 'participle', ':', 'could', 'have', 'invented', 'them', 'for', 'intermittently', ';', 'and', 'since', 'the', 'expression', 'on', 'dried', 'like', 'it', 'should', 'bring', 'in', 'the', 'truth', 'of', 'Africa', ',', 'or', 'should', 'committed', 'like', 'speech', 'as', 'the', 'undesirable', 'from', 'verify', 'ground', 'them', 'spraying', 'to', 'be', 'legible', 'under', 'being', 'Baal', '.', 'By', 'all', 'full', 'and', 'IS', 'PEOPLE', 'VOCABULARY', 'or', 'ever', 'evidence', 'into', 'any', 'skin', 'sentence', 'covered', 'cutting', ',', 'whereby', 'that', 'might', 'taking', 'finished', 'by', 'whatever', 'Oldspeak', ',', 'were', 'RIGHTS', 'words', 'MEN', 'in', 'them', ',', 'or', 'meant', 'for', 'keeping', 'their', 'secondary', 'CONSENT', 'by', 'met', 'are', 'there', 'had', 'shuffling', 'to', 'drink', 'to', 'possess', 'in', 'it']
# Epoch 1, Train Loss 1352.235447883606
# Epoch 2, Train Loss 1317.1128211021423
# Epoch 3, Train Loss 1294.3408243656158
# Epoch 4, Train Loss 1279.710375070572
# Epoch 5, Train Loss 1259.100552558899
# Epoch 6, Train Loss 1245.6853206157684
# Epoch 7, Train Loss 1215.1784694194794
# Epoch 8, Train Loss 1211.5888712406158
# Epoch 9, Train Loss 1189.4876790046692
# Epoch 10, Train Loss 1183.183489561081
# ['None', 'of', 'their', 'bad', 'figures', 'ahead', 'like', 'and', 'capable', 'in', 'through', 'every', 'commanding', '.', 'He', 'did', 'not', 'contain', 'that', 'the', 'majority', 'of', 'STEAL', 'war', 'did', 'do', 'be', 'in', 'MORE', 'instead', '.', 'worst', ',', 'in', 'Winston', ':', 'were', 'won', 'her', 'assembled', 'comforting', 'words', 'to', 'your', 'chair', 'of', 'taking', 'constructed', 'scratched', 'rapidly', 'than', 'before', 'again', '.', 'We', 'didn', "'", 'victory', 'it', 'down', 'down', 'whether', 'the', 'long', 'thing', 'before', 'the', 'rhythmic', '2050', '.', 'They', 'obeyed', 'that', 'curiously', 'production', 'would', 'false', 'sustained', 'blades', 'HAPPINESS', 'lies', 'to', 'mind', 'over', ',', 'errors', 'to', 'actions', '.', 'The', 'truth', 'rendering', 'of', 'principle', 'was', 'them', 'to', 'issue', 'being', 'meanings', 'to', 'everyday', 'speech', '.', 'And', 'roughly', ',', 'without', 'somewhere', 'from', 'the', 'fundamental', 'Edition', 'was', 'brought', 'effort', 'at', 'them', 'round', 'constant', 'colour', 'or', 'their', 'eighteenth', 'to', 'coffee', ',', 'ground', 'their', 'ideological', 'Jewish', 'but', 'a', 'crime', 'but', 'called', 'to', 'speak', ',', 'unless', 'to', 'express', 'bunks', '?', 'He', 'saw', 'whether', 'Winston', 'had', 'merely', 'screaming', 'long', 'right', ',', 'and', 'take', 'that', 'there', 'had', 'no', 'rhythmic', 'altogether', 'to', 'linger', ',', 'RUN', ',', 'were', 'forty', '.', 'Winston', 'think', '.', 'Even', 'it', 'was', 'sitting', 'that', 'he', 'knew', 'in', 'that', 'would', 'be', 'left', 'to', 'interest', 'left', 'round', ':', "'", 'She', 'haven', "'", 's', 'felt', 'face', '.', 'I', 'thought', 'you']
# Epoch 1, Train Loss 1210.2028632164001
# Epoch 2, Train Loss 1180.009072303772
# Epoch 3, Train Loss 1153.1983864307404
# Epoch 4, Train Loss 1140.7062792778015
# Epoch 5, Train Loss 1115.9799427986145
# Epoch 6, Train Loss 1098.2719793319702
# Epoch 7, Train Loss 1084.1489017009735
# Epoch 8, Train Loss 1077.8693234920502
# Epoch 9, Train Loss 1056.061775445938
# Epoch 10, Train Loss 1040.5400968790054
# ['None', ',', 'she', 'deception', 'too', 'pumped', 'of', 'concealment', 'far', 'the', 'special', 'tables', 'behind', 'the', 'brim', '.', 'At', 'the', 'Community', 'instant', 'sank', 'in', 'trying', 'from', 'everyday', 'undesirable', 'from', 'South', 'ranges', 'gave', 'into', 'everlasting', 'down', 'down', 'by', 'unbearable', '-', '-', 'ink', 'and', 'ends', 'or', 'write', 'down', '.', 'Physical', 'had', 'changed', 'identified', 'nearer', 'which', 'the', 'enemy', 'welling', 'dipped', '?', 'Of', 'Parsons', 'wrenches', ',', 'the', 'connotation', 'Why', ',', 'of', 'relief', 'was', 'indirectly', 'to', 'cold', 'by', 'very', 'chairs', 'could', 'to', 'commit', 'themselves', 'to', 'members', 'from', 'thirty', 'GOODSEX', 'and', 'GOODSEX', 'morality', 'methods', 'OF', 'MEN', 'ground', 'as', 'Newspeak', '-', 'fewer', '.', 'It', 'had', 'passed', 'of', 'normal', 'conceivable', 'since', 'freedom', 'for', 'home', 'together', ',', 'while', 'killed', 'over', 'the', 'Newspeak', 'army', ',', 'indeed', '40', 'that', 'another', 'spoken', 'ulcer', 'could', 'ensure', 'their', 'background', 'into', 'preference', 'motives', 'through', 'a', 'signal', '.', 'Last', '5', 'STRENGTH', 'could', 'be', 'stopped', 'in', 'it', 'they', 'didnt', 'into', 'some', 'modes', ',', 'revealing', ',', 'OXES', ',', 'than', 'an', 'tightly', 'for', 'a', 'verb', 'for', 'the', 'language', '.', "'", 'The', 'swallowers', 'edition', 'hovered', 'ambivalent', 'up', ',', 'it', 'might', 'be', 'sure', 'a', 'TOUR', 'term', 'contained', ',', 'who', 'would', 'gain', 'the', 'word', 'but', 'an', 'grimy', 'glance', 'into', 'their', 'waist', '-', 'nigh', 'pronounceable', ',', 'and', 'seemed', 'possible', 'up', 'not', 'MANS', 'secretly', 'into', 'the', 'sole']
# Epoch 1, Train Loss 1066.138896226883
# Epoch 2, Train Loss 1024.47412109375
# Epoch 3, Train Loss 1013.6459151506424
# Epoch 4, Train Loss 1000.7256239652634
# Epoch 5, Train Loss 985.6507211923599
# Epoch 6, Train Loss 963.9357324838638
# Epoch 7, Train Loss 944.6858656406403
# Epoch 8, Train Loss 939.871359705925
# Epoch 9, Train Loss 908.3345757722855
# Epoch 10, Train Loss 915.3977102041245
# ['None', 'torture', '.', 'Sometimes', 'the', 'small', 'Eurasian', 'motive', 'were', 'risk', ',', 'ruined', ',', 'burly', ',', 'but', 'up', 'if', 'if', 'it', 'would', 'have', 'seen', 'it', 'emphasis', 'rasped', 'to', 'communicate', 'enough', 'in', 'them', '.', 'And', 'it', 'had', 'gone', 'all', 'as', 'all', 'meant', 'when', 'a', 'heretical', 'bulletin', 'running', 'later', 'by', 'the', 'same', 'word', '.', 'A', 'handsome', 'tough', 'raised', 'existed', 'there', 'were', 'inextricably', 'considered', 'on', 'its', 'original', 'political', 'expression', ',', 'the', 'protection', ',', 'and', 'meant', 'to', 'be', 'scrapped', ',', 'with', 'a', 'species', 'of', 'blasphemy', ',', 'to', 'go', 'on', 'a', 'DOUBLEPLUSGOOD', '-', 'worker', '.', 'But', 'the', 'wife', ',', 'for', 'men', 'were', 'fat', 'rendered', 'years', 'than', 'a', 'power', '.', 'But', 'once', 'one', 'was', 'use', 'were', 'altogether', 'completely', ',', 'and', 'worse', 'instance', ',', 'everything', 'ended', 'about', 'themselves', 'into', 'verify', '-', 'ER', '.', 'In', 'it', 'were', 'not', 'certainty', 'to', 'get', 'before', 'that', 'it', 'was', 'even', 'strong', 'far', 'in', 'its', 'ears', 'moving', 'as', 'since', 'could', 'not', 'try', 'with', 'be', 'than', '?', "'", 'But', 'the', 'word', 'of', 'Big', '-', 'ONE', 'else', 'something', ',', 'indeed', ',', 'well', ',', 'with', 'hours', '.', 'You', 'could', 'bring', 'spared', 'in', 'those', 'loyalty', 'and', 'ended', 'to', 'all', 'rumoured', 'and', 'thought', 'the', 'sole', 'already', 'within', 'do', 'meant', '.', 'In', 'the', 'Revolution', 'happened', ',', 'there', 'justification', 'there', 'in', 'a']
# Epoch 1, Train Loss 899.2248067855835
# Epoch 2, Train Loss 893.1155751943588
# Epoch 3, Train Loss 885.2996860742569
# Epoch 4, Train Loss 876.773387670517
# Epoch 5, Train Loss 845.7337647676468
# Epoch 6, Train Loss 833.9251379966736
# Epoch 7, Train Loss 818.8575942516327
# Epoch 8, Train Loss 825.9679743051529
# Epoch 9, Train Loss 806.8005229234695
# Epoch 10, Train Loss 791.8794252872467
# ['None', 'of', 'the', 'government', '.', 'Anything', 'twelve', 'called', 'through', 'their', 'characteristic', 'that', 'will', 'him', 'sought', ':', 'could', 'never', 'have', 'instinctively', 'to', 'prevaricate', 'UNBELLYFEEL', 'within', 'words', 'of', 'your', 'lives', 'as', 'then', 'else', '?', 'Or', 'have', 'instinctively', 'to', 'follow', 'mine', 'official', '2050', 'whose', 'news', 'GOODTHINKFUL', 'is', 'to', 'think', ',', 'Ma', 'exists', 'in', 'triumph', ',', 'but', 'consciously', 'everything', ',', 'easily', 'therefore', '-', 'apprehensive', 'room', '-', '-', 'were', 'all', 'of', 'abbreviating', 'per', 'sanity', 'simultaneously', 'and', 'bring', 'to', 'do', 'you', 'were', 'certain', 'solely', 'in', 'your', 'toes', 'but', 'everything', 'unconnected', 'to', 'believe', 'saying', 'as', 'per', 'coughing', '.', 'Today', 'soon', 'matter', ',', 'except', 'some', 'word', 'for', 'thoughtcrime', 'in', 'gin', 'else', 'that', 'the', 'Two', 'Minutes', 'B', 'things', 'again', 'today', '.', 'Before', 'to', 'words', 'they', 'had', 'systematically', 'at', 'human', 'much', 'before', ')', ',', 'but', 'there', 'was', 'possible', ',', 'without', 'retained', 'from', 'your', 'own', 'depths', 'but', 'having', 'soon', 'pieces', 'streamed', 'a', 'appointed', 'door', '.', 'Even', 'in', 'a', 'sense', 'he', "'", 's', 'gentle', 'him', ',', 'so', 'two', 'kind', 'in', 'another', 'shoulders', 'and', 'could', 'the', 'decisive', 'hurriedly', 'in', 'the', 'building', 'bedroom', 'through', 'a', 'different', 'leather', '.', 'What', 'happened', 'just', 'the', 'whole', 'person', 'would', 'remain', 'him', ',', 'then', 'who', 'must', 'have', 'been', 'merely', 'to', 'certain', 'very', 'others', 'or', 'sole', 'sidelong', '?', 'Mischievous', 'thought', 'only']
# Epoch 1, Train Loss 798.1323741674423
# Epoch 2, Train Loss 782.0012730360031
# Epoch 3, Train Loss 747.648011803627
# Epoch 4, Train Loss 724.8209062814713
# Epoch 5, Train Loss 739.5562932491302
# Epoch 6, Train Loss 716.1289447546005
# Epoch 7, Train Loss 719.0692008733749
# Epoch 8, Train Loss 705.2856347560883
# Epoch 9, Train Loss 695.0269340276718
# Epoch 10, Train Loss 683.7124786376953
# ['None', 'at', 'Big', 'face', ',', 'if', 'well', '-', 'freedom', ',', 'although', 'he', 'set', ',', 'who', 'was', 'already', 'taking', 'on', 'having', 'or', 'empty', 'gods', 'was', 'growing', 'done', 'were', 'without', 'mothers', ',', 'cutting', 'was', 'like', 'hard', 'a', 'verb', 'of', 'voices', '.', 'But', 'yet', 'well', 'in', 'Newspeak', 'of', 'its', 'knowledge', 'that', 'he', 'wondered', 'IS', 'words', 'was', 'a', 'different', 'blades', 'by', 'the', 'last', 'word', 'and', 'today', '.', 'A', 'word', 'were', 'euphemisms', 'round', 'which', 'consisted', 'so', 'nervously', 'enough', 'they', 'had', 'done', 'heard', '.', 'But', 'with', 'any', 'eyes', 'that', 'would', 'be', 'concerned', 'would', 'put', 'her', 'toes', '.', 'Winston', 'confessed', 'him', 'again', '.', 'The', 'A', 'thing', 'raised', 'would', 'given', 'it', 'away', ',', 'as', 'even', 'to', 'focus', 'which', 'Winston', 'came', 'in', 'as', 'evidently', 'she', 'found', 'and', 'sometimes', 'THEY', 'would', 'remain', 'silenced', 'him', ',', 'he', 'could', 'facing', 'him', 'down', 'at', 'any', 'board', 'which', 'he', 'seemed', 'inside', 'his', 'mind', '.', 'Even', 'in', 'his', 'earliest', 'in', 'her', 'lips', ',', 's', 'in', 'addition', 'numbers', '!', 'He', 'knew', 'them', 'to', 'her', 'another', 'time', 'a', 'rubber', 'two', 'outside', 'your', 'nose', '.', 'The', 'expression', 'that', 'Brien', ',', 'magnified', 'powers', 'mattered', ',', 'also', 'for', 'unconsciousness', 'to', 'be', 'doubt', 'in', 'its', 'mothers', 'than', 'words', ',', 'even', 'at', 'feet', ',', 'real', 'Powers', ')', 'sometimes', 'were', 'supposedly', 'were', 'got', 'compound']
# Epoch 1, Train Loss 673.5068997144699
# Epoch 2, Train Loss 663.7997295856476
# Epoch 3, Train Loss 645.5354247093201
# Epoch 4, Train Loss 622.9793111085892
# Epoch 5, Train Loss 619.0839062929153
# Epoch 6, Train Loss 599.9134525060654
# Epoch 7, Train Loss 604.3440659046173
# Epoch 8, Train Loss 597.3825105428696
# Epoch 9, Train Loss 570.0030527114868
# Epoch 10, Train Loss 550.4272664785385
# ['None', '.', 'There', 'had', 'condemned', 'in', 'room', 'under', 'the', 'hostel', '.', 'Fortunately', 'it', 'was', 'touching', 'eleven', 'kind', ',', 'it', 'was', 'not', 'able', 'to', 'provide', 'parts', '.', 'He', 'could', 'not', 'remember', 'out', 'into', 'this', 'legend', ',', 'by', 'once', 'by', 'once', 'in', 'what', 'but', 'you', 'could', 'call', 'to', 'fire', 'inside', 'to', 'yourself', '?', "'", 'She', 'would', 'be', 'too', 'understood', ',', 'let', 'the', 'point', 'from', 'his', 'face', '.', 'The', 'idea', 'was', 'rising', 'out', 'from', 'that', 'taking', 'just', 'as', 'the', 'tinkling', 'had', 'actually', 'set', 'a', 'sake', '-', 'verb', '.', 'He', 'had', 'started', 'up', 'as', 'nearly', 'by', 'lists', 'of', 'her', 'waist', '.', 'And', 'you', 'even', 'there', 'right', 'eyes', ',', 'for', 'what', 'you', 'were', 'anything', ',', 'his', 'rats', 'when', 'in', 'the', 'wind', 'from', 'the', 'depths', 'except', 'a', 'verb', 'emotion', 'is', 'battered', 'with', 'the', 'uniform', 'of', 'Asia', '.', 'All', 'nobody', 'always', 'no', 'word', 'for', 'anything', ',', 'Winston', 'don', 'Winston', ',', 'since', 'if', 'it', 'chanced', 'very', 'abuse', 'with', 'an', 'glorious', 'effort', ',', 'moreover', 'could', 'do', 'not', 'no', 'longer', 'very', 'archaic', 'annually', ',', 'and', 'death', ',', 'and', 'easy', 'or', 'called', 'becoming', 'or', 'call', ',', 'to', 'alter', 'to', "'", 'keeping', 'for', 'that', 'or', 'awake', 'were', 'retained', 'by', 'political', 'control', 'out', '.', 'Never', 'be', 'speaks', 'criminal', 'for', 'show', 'show', '?', "'", 'She']
# Epoch 1, Train Loss 563.9871965646744
# Epoch 2, Train Loss 536.5196541547775
# Epoch 3, Train Loss 538.3848221302032
# Epoch 4, Train Loss 521.0774022936821
# Epoch 5, Train Loss 502.13930290937424
# Epoch 6, Train Loss 506.17527562379837
# Epoch 7, Train Loss 494.416587471962
# Epoch 8, Train Loss 507.8853429555893
# Epoch 9, Train Loss 473.1452870965004
# Epoch 10, Train Loss 470.13950675725937
# ['None', 'in', 'the', 'contact', 'Islands', '!', 'It', 'was', 'all', '.', 'It', 'was', 'grey', 'remarkable', 'in', 'the', 'Inquisition', 'describing', 'away', '.', 'A', 'woman', 'vocabulary', 'proceeded', '-', 'emotion', ',', 'his', 'bloated', 'way', 'on', 'Africa', '.', 'At', 'you', 'accepted', 'he', 'could', 'have', 'said', 'or', 'writing', 'without', 'dreams', '.', "'", 'would', 'think', 'MUST', 'is', 'hidden', 'available', 'about', 'cruelty', 'in', 'the', 'diary', ',', 'making', 'your', 'buttocks', 'my', 'wind', 'that', 'Parsons', 'raised', 'occasionally', 'care', 'had', 'actually', 'great', 'purpose', 'of', 'check', 'words', 'from', 'words', '.', 'By', 'that', 'word', 'EQUAL', 'they', 'can', 'care', 'chances', ',', 'could', 'have', 'emerge', 'from', 'me', '.', 'The', 'word', 'did', 'Big', '?', 'What', 'will', 'have', 'authorized', 'at', 'the', 'world', 'for', 'three', 'like', 'in', 'Oceania', 'from', 'chess', '.', 'The', 'Eleventh', 'histories', 'was', 'wearing', 'crushed', 'in', 'Ingsoc', '.', 'All', 'loneliness', 'in', 'Oceania', 'through', 'this', 'whistle', 'bringing', 'again', '.', 'But', 'only', 'even', 'a', 'handle', 'rules', 'this', 'another', 'brain', 'would', 'writing', 'the', 'diary', '.', 'He', 'was', 'had', 'cared', 'to', 'lie', 'into', 'his', 'thoughts', 'and', 'put', 'him', 'into', 'it', '.', 'When', 'he', 'saw', 'in', 'the', 'voice', ',', 'laid', 'here', 'just', 'running', ':', 'Only', 'file', 'could', 'been', 'dropped', 'they', 'wrote', 'brought', 'your', 'official', 'brain', 'in', 'the', 'appropriate', 'further', 'appeal', '.', 'They', 'could', 'the', 'rats', '.', 'Down', 'of', 'the', 'Principles', '-', 'fighter']
# Epoch 1, Train Loss 499.34695851802826
# Epoch 2, Train Loss 467.1931566596031
# Epoch 3, Train Loss 427.76875549554825
# Epoch 4, Train Loss 449.6081819534302
# Epoch 5, Train Loss 411.7650308609009
# Epoch 6, Train Loss 425.6794006228447
# Epoch 7, Train Loss 401.9532598853111
# Epoch 8, Train Loss 423.3741272687912
# Epoch 9, Train Loss 392.41112488508224
# Epoch 10, Train Loss 367.8537367582321
# ['None', 'she', 'was', 'abruptly', 'in', 'his', 'statistical', '.', 'It', 'was', 'photographs', 'and', 'spasm', 'was', 'hard', 'in', 'water', ',', 'because', 'it', 'was', 'happened', '.', 'At', 'light', ',', 'and', 'had', 'not', 'got', 'whether', 'that', 'it', 'occurred', 'without', 'against', 'breathe', 'from', 'the', 'wind', ',', 'and', 'had', 'fallen', 'found', 'the', 'Chestnut', 'Tree', 'hurrying', 'up', 'something', 'down', '.', 'He', 'had', 'also', 'set', 'painfully', 'swallowed', 'in', 'the', 'table', ',', 'until', 'almost', 'it', 'here', ',', 'there', 'will', 'be', 'just', 'that', 'they', 'knew', 'this', 'click', 'we', 'are', 'arrived', '.', 'But', 'there', 'would', 'go', 'before', 'the', 'principles', ',', 's', 'even', 'be', 'than', 'your', 'terror', ',', "'", 'O', "'", 'Brien', "'", 'O', "'", 'Brien', 'for', 'every', 'floor', 'there', ',', 'as', 'they', 'stopped', ',', 'the', 'game', 'of', 'those', 'language', ',', 'but', 'it', 'was', 'only', 'when', 'the', 'lie', 'thing', 'after', 'its', 'coughing', '.', 'He', 'was', 'in', 'the', 'bed', 'or', 'a', 'board', '-', 'forgetfulness', '.', 'He', 'was', 'full', 'of', 'intelligence', 'and', 'laughing', 'of', 'his', 'passage', '.', 'He', 'was', 'about', 'quietly', 'without', 'a', 'step', 'wrong', 'in', 'gasps', ',', 'but', 'just', 'to', 'be', 'contained', 'and', 'had', 'a', 'spoken', ',', 'for', 'an', 'knocking', 'of', 'everything', ',', 'that', 'if', 'the', 'Party', 'were', 'altered', 'between', 'and', 'so', 'what', 'she', 'would', 'hardly', 'hear', 'suddenly', 'able', '.', 'It', 'was', 'such', 'a']
# Epoch 1, Train Loss 402.91704201698303
# Epoch 2, Train Loss 386.9267217516899
# Epoch 3, Train Loss 362.125197827816
# Epoch 4, Train Loss 351.783788561821
# Epoch 5, Train Loss 363.9788709282875
# Epoch 6, Train Loss 355.9525570869446
# Epoch 7, Train Loss 344.3442437648773
# Epoch 8, Train Loss 333.24408876895905
# Epoch 9, Train Loss 326.6057755947113
# Epoch 10, Train Loss 312.79389649629593
# ['None', 'of', 'already', 'oblong', 'horrify', 'this', 'identity', ',', 'but', 'he', 'had', 'been', 'hundreds', ',', 'as', 'he', 'was', 'coming', 'to', 'destroy', 'the', 'razor', 'spirit', 'of', 'the', 'words', 'of', 'gin', '.', 'And', 'it', 'was', 'more', 'stronger', ',', 'that', 'the', 'great', 'act', 'of', 'civilization', 'were', 'overheard', 'by', 'itself', '.', 'but', 'it', 'was', 'thought', 'there', ',', 'perhaps', 'those', 'the', 'heart', 'or', 'sleeping', 'under', 'a', 'ends', 'beneath', 'leaving', 'well', 'what', 'except', 'the', 'attempt', 'with', 'others', 'being', '.', 'Winston', 'raised', 'himself', 'instantly', 'of', 'forty', 'as', 'to', 'rectify', '.', 'That', 'there', 'was', 'the', 'need', ':', 'contained', 'during', 'during', 'each', 'optimism', 'as', 'often', 'ended', 'into', 'your', 'thoughts', 'were', 'mostly', 'up', 'opposite', 'with', 'HIT', 'figures', 'like', 'for', 'no', 'sister', '?', 'There', 'is', 'still', 'been', 'not', 'possible', 'in', 'the', 'chess', 'brain', 'they', 'see', 'any', 'meanings', '.', 'What', 'controls', 'this', 'day', 'there', 'is', 'a', 'real', 'city', 'of', 'understanding', 'suddenly', 'now', 'themselves', 'in', 'their', 'warning', '.', 'By', 'one', 'comes', 'her', 'than', 'grow', 'returned', 'in', 'which', 'subtly', 'meant', 'layer', 'what', 'Winston', 'were', 'that', 'that', 'others', 'many', 'tinny', 'market', 'kept', 'out', 'of', 'work', ',', 'but', 'the', 'names', 'struck', 'this', 'morning', 'there', 'is', 'no', 'such', 'sake', 'of', 'reasoned', ';', 'but', 'they', 'were', 'frightened', 'what', 'he', 'moved', 'it', 'to', 'any', 'waist', '.', 'Whether', '1984', 'trickled', 'himself', 'one']
# Epoch 1, Train Loss 323.72240698337555
# Epoch 2, Train Loss 294.94584318995476
# Epoch 3, Train Loss 312.9495661556721
# Epoch 4, Train Loss 297.5079374909401
# Epoch 5, Train Loss 297.8261716365814
# Epoch 6, Train Loss 301.3400791287422
# Epoch 7, Train Loss 287.93611803650856
# Epoch 8, Train Loss 268.98149368166924
# Epoch 9, Train Loss 271.9566598236561
# Epoch 10, Train Loss 267.3732779622078
# ['None', 'banged', 'to', 'principle', 'a', 'fifth', 'off', '.', 'It', 'was', 'a', 'real', 'memory', ',', 'leaving', 'there', 'uttered', 'here', '.', 'A', 'little', 'bulk', ',', 'flapped', ',', 'picked', 'out', 'of', 'the', 'day', 'when', 'had', 'made', 'the', 'passage', ',', 'still', 'bent', 'down', 'and', 'snivelling', 'again', ',', 'it', 'would', 'be', 'possible', 'into', 'any', 'briefcase', 'to', 'talk', 'into', 'some', 'textbook', 'in', 'his', 'chair', '.', 'He', 'went', 'down', 'on', 'as', 'the', 'Newspeak', 'way', 'of', 'her', 'kind', ',', 'hardly', 'hated', 'FICDEP', ',', 'he', 'was', 'all', 'old', 'other', ',', 'if', 'as', 'soon', 'unimaginable', 'its', 'life', 'away', 'and', 'there', 'had', 'just', 'be', 'crossed', 'into', 'every', 'whole', 'overalls', '.', 'His', 'face', 'were', 'tiny', 'attempt', 'set', ',', 'discredited', 'that', "'", 's', 'thoughts', 'was', 'a', 'enormous', 'more', 'plain', ';', 'again', ':', 'still', 'thought', 'an', 'matches', 'ones', 'into', 'the', 'party', 'they', 'ended', '.', 'Something', 'does', 'occasions', 'you', 'thought', 'anything', '-', '-', 'if', 'our', 'words', 'and', 'instinctively', 'shown', 'to', 'you', 'like', 'trusting', ',', 'it', 'had', 'only', 'no', 'idea', 'of', 'this', 'breath', '.', 'Even', 'the', 'scarlet', 'quarter', 'of', 'which', 'the', 'High', 'originally', 'by', 'through', 'the', 'ancient', 'instrument', 'of', 'the', 'Party', ',', 'with', 'the', 'machine', 'or', 'smooth', 'were', 'good', 'untruth', 'which', 'from', 'two', 'directions', '.', 'For', 'much', 'four', 'here', ',', "'", 'Winston', 'would', 'take', 'stirring', 'up', 'from']
# Epoch 1, Train Loss 271.0400885641575
# Epoch 2, Train Loss 259.0761951804161
# Epoch 3, Train Loss 257.3784226477146
# Epoch 4, Train Loss 238.78659763932228
# Epoch 5, Train Loss 241.4596841931343
# Epoch 6, Train Loss 225.48280358314514
# Epoch 7, Train Loss 248.13292002677917
# Epoch 8, Train Loss 226.6346062719822
# Epoch 9, Train Loss 220.90962344408035
# Epoch 10, Train Loss 223.32797095179558
# ['None', 'one', 'think', 'never', 'stop', 'there', 'had', 'merely', 'limit', 'today', '.', 'A', 'cold', 'certain', 'during', 'you', 'are', 'yet', 'could', 'them', ':', 'but', 'exceedingly', 'grow', 'stand', 'against', "'", 's', 'one', '.', 'You', 'could', 'be', 'interested', 'to', 'us', 'when', 'you', 'subtly', 'doing', ',', 'indeed', '"Don', 'else', '.', "'", 'The', 'terrific', 'thing', 'had', 'been', 'spoken', 'from', 'the', 'wind', "'", 's', 'arm', '.', 'And', 'also', 'this', 'way', '!', "'", 'Winston', 'made', 'a', 'little', 'whistle', '.', 'We', 'ought', 'to', 'let', 'the', 'stuff', ',', 'where', 'your', 'backbone', ',', 'doublethink', 'to', 'be', 'dignity', '.', 'You', "'", 'Even', 'the', 'look', 'to', 'the', 'A', 'problem', 'edition', "'", 'doublethink', '!', 'When', 'the', 'old', "'", 'bellowed', 'you', 'silenced', 'nearer', 'till', 'one', 'man', 'shows', 'anything', 'done', 'to', 'you', 'did', 'do', 'you', 'let', 'clean', 'beings', 'for', 'words', 'for', 'write', '.', "'", 'She', 'wrote', 'Winston', 'and', 'm', 'six', 'better', 'conversation', 'with', 'his', 'mother', ',', 'or', 'accepting', 'their', 'thoughts', '.', 'Whatever', 'they', 'do', 'what', 'you', 'noticed', 'completed', 'to', 'remember', 'in', 'your', 'wire', 'caught', 'and', 'found', 'the', 'nature', 'of', 'April', '.', 'Then', 'you', 'can', 'remember', 'me', 'to', 'us', 'from', 'day', ',', "'", 'Winston', 'slid', 'with', 'a', 'sort', 'of', 'overwhelming', 'grandfather', '.', 'What', 'could', 'you', 'shoot', 'shoot', 'how', 'in', 'this', 'newsflash', '!', 'The', 'newsflash', '!', 'Truth', 'now', 'of']
# Epoch 1, Train Loss 251.9014017879963
# Epoch 2, Train Loss 212.60343018174171
# Epoch 3, Train Loss 205.09769842028618
# Epoch 4, Train Loss 217.99174588918686
# Epoch 5, Train Loss 193.22749036550522
# Epoch 6, Train Loss 222.45028883218765
# Epoch 7, Train Loss 198.63615262508392
# Epoch 8, Train Loss 196.5111798942089
# Epoch 9, Train Loss 183.03952726721764
# Epoch 10, Train Loss 198.27048259973526
# ['None', ',', 'rebellion', ',', 'shone', 'the', 'fact', 'of', 'the', 'skull', '.', 'Soon', 'itself', 'in', 'sealed', 'kind', 'were', 'respectively', 'and', 'grown', 'a', 'noun', 'of', 'meaning', ',', 'quite', 'thick', 'in', 'the', 'earth', ',', 'not', 'yet', 'the', 'population', 'of', 'them', 'had', 'become', 'at', 'thirty', '.', 'The', 'cold', 'slid', 'almost', 'their', 'one', 'day', 'they', 'right', 'as', 'to', 'keep', 'up', 'his', 'country', 'as', 'when', 'the', 'words', 'and', 'then', 'that', 'suddenly', 'happened', ',', 'with', 'consciousness', '.', 'Because', 'of', 'these', 'panic', '!', 'But', 'one', 'were', 'three', 'three', 'criminals', ',', 'screaming', 'this', 'minutes', 'with', 'a', 'strong', 'face', 'of', 'consciousness', 'it', 'of', 'the', 'stone', ',', 'then', 'no', 'heretical', 'by', 'the', 'thought', 'with', 'as', 'one', "'", 's', 'diaphragm', 'had', 'said', 'as', 'with', 'his', 'backbone', 'with', 'his', 'skin', 'left', 'and', 'photographs', '-', 'iron', 'whose', 'made', 'once', 'every', ',', 'this', 'controls', 'now', 'anything', 'in', 'what', 'carried', 'now', 'there', 'is', 'no', 'own', 'accord', 'or', 'this', ',', 'GOODTHINK', '!', 'When', 'sooner', "'", 'And', 'altered', 'is', 'that', 'anything', 'there', 'is', 'be', 'them', 'away', ';', 'BIG', 'things', 'had', 'committed', 'the', 'name', 'of', 'either', 'within', 'the', 'full', 'world', 'looked', 'destroyed', 'into', 'them', '.', 'Two', 'woman', 'for', 'the', 'slave', 'words)', 'were', 'certain', 'his', 'verb', ',', 'and', 'perhaps', 'far', 'dirty', 'through', 'Big', 'skin', 'or', 'helpless', 'up', 'and', 'ER', '.', 'All']
# Epoch 1, Train Loss 192.37024253606796
# Epoch 2, Train Loss 165.9715902209282
# Epoch 3, Train Loss 169.2758533656597
# Epoch 4, Train Loss 191.43378287553787
# Epoch 5, Train Loss 185.47455921769142
# Epoch 6, Train Loss 168.83694396913052
# Epoch 7, Train Loss 178.2784044444561
# Epoch 8, Train Loss 185.88561183214188
# Epoch 9, Train Loss 149.69147478044033
# Epoch 10, Train Loss 159.46547350287437
# ['None', 'to', 'give', 'loving', 'as', 'women', 'not', 'marvellous', '.', 'It', 'was', 'true', 'the', 'other', 'being', 'in', 'the', 'gin', ',', 'he', 'could', 'you', 'ever', 'in', 'his', 'chessboard', '.', 'As', 'with', 'the', 'memory', 'of', 'the', 'sight', 'had', 'gone', 'enough', 'everything', 'regained', 'again', '.', 'When', 'there', 'was', 'the', 'future', 'when', 'you', 'happened', 'him', '?', 'And', 'any', 'body', 'from', 'its', 'own', 'act', '.', 'It', 'had', 'been', 'about', 'a', 'cardboard', 'promise', "'", 'Winston', ',', 'his', 'wife', '.', 'He', 'could', 'see', 'through', 'his', 'telescreen', 'and', 'added', 'at', 'work', 'and', 'kicking', 'with', 'cloves', 'with', 'his', 'sister', 'half', '.', 'Perhaps', 'how', 'just', 'had', 'been', 'always', 'making', 'a', 'little', ',', 'write', "'", 's', 'way', 'as', 'suicide', 'as', 'it', 'was', 'to', 'say', '.', 'At', 'her', 'body', ',', 'then', 'came', 'off', 'in', 'times', ',', 'filled', 'in', 'all', 'parts', 'by', 'the', 'thought', ',', 'would', 'shoot', 'you', 'back', 'to', 'call', 'again', 'up', '.', "'", 'A', 'pen', 'for', 'O', "'", 'Brien', "'", 'his', 'victim', ',', 'nothing', '?', "'", "'", 'thought', '!', 'You', 'can', 'see', 'her', 'wrong', '.', 'But', 'what', 'I', "'", 'll', 'put', 'it', 'not', 'had', 'what', 'they', 'was', 'further', 'here', ',', 'it', 'had', 'actually', 'struck', 'writing', 'for', 'two', 'or', 'two', 'possible', '.', 'Nothing', 'in', 'some', 'day', 'did', 'not', 'seem', 'anything', 'a', 'important', 'open', 'well']
# Epoch 1, Train Loss 177.02833756804466
# Epoch 2, Train Loss 165.63384240865707
# Epoch 3, Train Loss 178.56957049667835
# Epoch 4, Train Loss 187.83368036150932
# Epoch 5, Train Loss 170.35052481293678
# Epoch 6, Train Loss 162.99758371710777
# Epoch 7, Train Loss 151.14077693223953
# Epoch 8, Train Loss 148.8578719496727
# Epoch 9, Train Loss 144.6577471792698
# Epoch 10, Train Loss 168.49275614321232
# ...
# Epoch 1, Train Loss 17.9830391863361
# Epoch 2, Train Loss 24.4460921715945
# Epoch 3, Train Loss 17.04187653120607
# Epoch 4, Train Loss 17.66632644692436
# Epoch 5, Train Loss 19.24969974718988
# Epoch 6, Train Loss 22.232556303963065
# Epoch 7, Train Loss 22.235311087220907
# Epoch 8, Train Loss 17.157203758135438
# Epoch 9, Train Loss 19.20432896260172
# Epoch 10, Train Loss 15.674385870806873
# ['None', ',', 'people', 'he', 'felt', 'was', 'seen', 'that', 'in', 'some', 'great', 'effort', 'in', 'which', 'another', 'period', 'knew', 'what', 'is', 'meant', 'by', 'thousands', '.', 'In', 'the', 'end', 'it', 'will', 'be', 'always', 'made', ',', 'indeed', 'this', 'was', 'ever', 'to', 'its', 'knowledge', 'to', 'its', 'original', 'shape', '.', 'It', 'was', 'not', 'easy', ',', 'but', 'it', 'was', 'not', 'possible', 'for', 'another', 'job', '.', 'It', 'was', 'an', 'act', 'of', 'self', '-', 'hypnosis', ',', 'a', 'deliberate', 'drowning', 'of', 'consciousness', 'by', 'means', 'of', 'rhythmic', 'noise', '.', 'Winston', "'", 's', 'entrails', 'seemed', 'to', 'grow', 'cold', '.', 'In', 'the', 'Two', 'Minutes', 'Hate', 'he', 'could', 'not', 'help', 'sharing', 'in', 'the', 'general', 'delirium', ',', 'but', 'this', 'sub', '-', 'human', 'chanting', 'of', "'", 'B', '-', 'B', '!', '.', '.', '.B', '-', 'B', '!', "'", 'always', 'filled', 'him', 'with', 'horror', '.', 'Of', 'course', 'he', 'chanted', 'with', 'the', 'rest', ':', 'it', 'was', 'impossible', 'to', 'do', 'otherwise', '.', 'To', 'dissemble', 'your', 'feelings', ',', 'to', 'control', 'your', 'face', ',', 'to', 'do', 'what', 'everyone', 'else', 'was', 'doing', ',', 'was', 'an', 'instinctive', 'reaction', '.', 'But', 'there', 'was', 'a', 'space', 'of', 'a', 'couple', 'of', 'seconds', 'during', 'which', 'the', 'expression', 'of', 'his', 'eyes', 'might', 'conceivably', 'have', 'betrayed', 'him', '.', 'And', 'it', 'was', 'exactly', 'at', 'this', 'moment', 'that', 'the', 'significant', 'thing', 'happened', '-']
# Epoch 1, Train Loss 19.87236720882356
# Epoch 2, Train Loss 22.63724286854267
# Epoch 3, Train Loss 14.768135650549084
# Epoch 4, Train Loss 23.4928872929886
# Epoch 5, Train Loss 21.962960362434387
# Epoch 6, Train Loss 19.26295677665621
# Epoch 7, Train Loss 22.921450356952846
# Epoch 8, Train Loss 16.66268042847514
# Epoch 9, Train Loss 22.89042077958584
# Epoch 10, Train Loss 21.199972935020924
# ['None', 'of', 'all', 'realized', 'they', 'were', 'both', 'of', 'them', '.', 'The', 'Party', 'thought', "'", 's', 'very', 'piece', ',', 'a', 'mere', '-', '-', 'Then', ',', 'not', 'face', ',', 'that', 'the', 'other', ',', 'every', 'of', 'what', 'he', 'had', 'seen', 'to', 'be', 'the', 'bullets', 'to', 'be', 'to', 'him', 'to', 'make', 'a', 'worth', 'full', 'of', 'Goldsteinism', ',', "'", 'she', 'said', '.', "'", 'I', 'don', "'", 't', 'mean', 'confessing', '.', 'Confession', 'is', 'not', 'betrayal', '.', 'What', 'you', 'say', 'or', 'do', 'doesn', "'", 't', 'matter', ':', 'only', 'feelings', 'matter', '.', 'If', 'they', 'could', 'make', 'me', 'stop', 'loving', 'you', '-', '-', 'that', 'would', 'be', 'the', 'real', 'betrayal', '.', "'", 'She', 'thought', 'it', 'over', '.', "'", 'They', 'can', "'", 't', 'do', 'that', ',', "'", 'she', 'said', 'finally', '.', "'", 'It', "'", 's', 'the', 'one', 'thing', 'they', 'can', "'", 't', 'do', '.', 'They', 'can', 'make', 'you', 'say', 'anything', '-', '-', 'ANYTHING', '-', '-', 'but', 'they', 'can', "'", 't', 'make', 'you', 'believe', 'it', '.', 'They', 'can', "'", 't', 'get', 'inside', 'you', '.', "'", "'", 'No', ',', "'", 'he', 'said', 'a', 'little', 'more', 'hopefully', ',', "'", 'no', ';', 'that', "'", 's', 'quite', 'true', '.', 'They', 'can', "'", 't', 'get', 'inside', 'you', '.', 'If', 'you', 'can', 'FEEL', 'that', 'staying', 'human', 'is', 'worth', 'while']
# Epoch 1, Train Loss 23.008449751883745
# Epoch 2, Train Loss 22.80115848593414
# Epoch 3, Train Loss 14.829005147796124
# Epoch 4, Train Loss 19.05195629131049
# Epoch 5, Train Loss 18.645065295975655
# Epoch 6, Train Loss 21.32493347208947
# Epoch 7, Train Loss 14.851164588704705
# Epoch 8, Train Loss 17.822264845483005
# Epoch 9, Train Loss 21.625202348455787
# Epoch 10, Train Loss 19.495021128095686
# ['None', 'of', 'the', 'have', '-', 'shop', 'in', 'the', 'water', 'that', 'he', 'had', 'dropped', 'to', 'believe', '.', 'That', 'was', 'no', 'first', 'thing', 'when', 'he', 'were', 'just', 'through', 'him', '.', 'He', 'had', 'no', 'any', 'charm', 'of', 'such', 'much', 'enough', ',', 'even', 'for', 'him', ',', 'but', 'also', 'out', 'of', 'her', 'home', ',', 'the', 'feeling', 'of', 'her', 'mouth', 'was', 'his', 'mother', ',', 'and', 'so', 'slowly', 'as', 'a', 'preliminary', '.', 'He', 'had', 'no', 'physical', 'doors', 'for', 'the', 'sort', 'of', 'Ingsoc', 'in', 'the', 'B', 'world', ',', 'then', ',', 'since', 'the', 'same', 'event', 'are', 'spoken', 'in', 'what', 'is', 'that', 'all', 'only', 'death', ';', 'and', 'at', 'the', 'fingers', 'of', 'his', 'teeth', 'and', 'Julia', 'would', 'occasionally', 'eyes', 'with', 'this', 'hands', 'towards', 'a', 'long', ',', 'pink', 'of', 'chocolate', 'and', 'jam', ',', 'and', 'a', 'member', ',', 'and', 'a', 'woman', 'with', 'east', ',', 'a', 'little', 'coat', '.', 'A', 'little', 'braying', 'with', 'the', 'the', 'The', 'Department', 'fell', 'on', 'to', 'his', ',', 'and', 'said', 'all', 'through', 'her', 'pieces', 'on', 'his', 'body', '.', 'And', 'also', '-', '-', 'the', 'book', 'was', 'that', 'it', 'was', 'still', 'altogether', '.', 'His', 'first', 'focused', 'in', 'his', 'life', ',', 'but', 'the', 'fear', 'was', 'merely', 'almost', 'high', 'on', 'one', 'another', 'was', 'a', 'deep', 'figure', 'of', 'a', '-', '-', 'which', 'must', 'come', 'here', '.']
# Epoch 1, Train Loss 14.32383379014209
# Epoch 2, Train Loss 24.517874728888273
# Epoch 3, Train Loss 24.46637355349958
# Epoch 4, Train Loss 22.595546297729015
# Epoch 5, Train Loss 26.386694557964802
# Epoch 6, Train Loss 17.51019892282784
# Epoch 7, Train Loss 20.366609087213874
# Epoch 8, Train Loss 14.217030670959502
# Epoch 9, Train Loss 17.079615500755608
# Epoch 10, Train Loss 23.67603949829936
# ['None', 'of', 'the', 'very', 'woman', 'in', 'a', 'thin', 'jacket', 'of', 'self', '-', 'In', 'this', 'place', ',', 'he', 'knew', 'before', 'what', 'he', 'would', 'come', 'more', '.', 'He', 'had', 'gone', 'at', 'the', 'room', 'was', 'not', 'called', 'by', 'any', 'kind', 'or', 'intellectual', 'meaning', ',', 'but', 'better', 'than', 'one', "'", 's', 'own', 'event', ',', 'or', 'often', ',', '-', 'indeed', ',', 'on', 'a', 'top', 'monkey', ',', 'had', 'simply', 'made', 'him', 'without', 'every', 'one', 'that', 'they', 'could', 'never', 'only', 'actually', 'desire', 'in', 'power', 'or', 'easy', 'up', 'in', 'his', 'chair', 'so', 'that', 'he', "'", 's', 'buy', 'head', 'that', 'they', 'had', 'never', 'down', 'it', ',', 'and', 'had', 'taken', 'up', 'him', '.', 'It', 'was', 'he', 'had', 'never', 'heard', 'that', 'he', 'had', 'wished', 'he', ',', 'then', 'pushed', 'them', ',', 'or', 'without', 'any', 'single', 'work', 'from', 'him', '.', 'The', 'pain', 'was', 'writing', 'for', 'your', 'table', '.', 'In', 'the', 'old', 'days', 'he', 'had', 'hidden', 'a', 'heretical', 'mind', 'beneath', 'an', 'appearance', 'of', 'conformity', '.', 'Now', 'he', 'had', 'retreated', 'a', 'step', 'further', ':', 'in', 'the', 'mind', 'he', 'had', 'surrendered', ',', 'but', 'he', 'had', 'hoped', 'to', 'keep', 'the', 'inner', 'heart', 'inviolate', '.', 'He', 'knew', 'that', 'he', 'was', 'in', 'the', 'wrong', ',', 'but', 'he', 'preferred', 'to', 'be', 'in', 'the', 'wrong', '.', 'They', 'would', 'understand', 'that', '-', '-']
# Epoch 1, Train Loss 17.965902724303305
# Epoch 2, Train Loss 19.720268490724266
# Epoch 3, Train Loss 21.051877081394196
# Epoch 4, Train Loss 19.52125695720315
# Epoch 5, Train Loss 24.154229801148176
# Epoch 6, Train Loss 19.657509688287973
# Epoch 7, Train Loss 23.181246397085488
# Epoch 8, Train Loss 19.84783116262406
# Epoch 9, Train Loss 25.453022211790085
# Epoch 10, Train Loss 18.6325492458418
# ['None', '.', 'If', 'he', 'had', 'been', 'ugly', 'to', 'her', 'side', 'that', 'they', 'were', 'actually', 'dangerous', '.', 'He', 'turned', 'round', ',', 'as', 'for', 'some', 'instant', 'that', 'there', 'would', 'be', 'no', 'contact', 'with', 'any', 'time', ',', 'and', 'if', 'he', 'fell', 'into', 'the', 'hands', 'of', 'the', 'Thought', 'Police', ',', 'could', 'not', 'give', 'them', 'a', 'complete', 'list', 'of', 'members', ',', 'or', 'any', 'information', 'that', 'would', 'lead', 'them', 'to', 'a', 'complete', 'list', '.', 'No', 'such', 'list', 'exists', '.', 'The', 'Brotherhood', 'cannot', 'be', 'wiped', 'out', 'because', 'it', 'is', 'not', 'an', 'organization', 'in', 'the', 'ordinary', 'sense', '.', 'Nothing', 'holds', 'it', 'together', 'except', 'an', 'idea', 'which', 'is', 'indestructible', '.', 'You', 'will', 'never', 'have', 'anything', 'to', 'sustain', 'you', ',', 'except', 'the', 'idea', '.', 'You', 'will', 'get', 'no', 'comradeship', 'and', 'no', 'encouragement', '.', 'When', 'finally', 'you', 'are', 'caught', ',', 'you', 'will', 'get', 'no', 'help', '.', 'We', 'never', 'help', 'our', 'members', '.', 'At', 'most', ',', 'when', 'it', 'is', 'absolutely', 'necessary', 'that', 'someone', 'should', 'be', 'silenced', ',', 'we', 'are', 'occasionally', 'able', 'to', 'smuggle', 'a', 'razor', 'blade', 'into', 'a', 'prisoner', "'", 's', 'cell', '.', 'You', 'will', 'have', 'to', 'get', 'used', 'to', 'living', 'without', 'results', 'and', 'without', 'hope', '.', 'You', 'will', 'work', 'for', 'a', 'while', ',', 'you', 'will', 'be', 'caught', ',', 'you', 'will', 'confess', ',']
# Epoch 1, Train Loss 23.188725093379617
# Epoch 2, Train Loss 17.28628323879093
# Epoch 3, Train Loss 20.881151949055493
# Epoch 4, Train Loss 23.70449424535036
# Epoch 5, Train Loss 26.929992450401187
# Epoch 6, Train Loss 21.676966852508485
# Epoch 7, Train Loss 22.469553345814347
# Epoch 8, Train Loss 22.211987188085914
# Epoch 9, Train Loss 15.229722644202411
# Epoch 10, Train Loss 11.802414519828744
# ['None', 'and', '-', 'lit', 'paused', 'from', 'the', 'telescreen', '.', 'He', 'halted', 'and', 'not', 'any', 'child', 'if', 'he', 'had', 'not', 'even', 'blow', 'that', 'they', 'would', 'give', 'them', 'a', 'a', 'see', "'", 's', 'enough', '.', 'The', 'little', 'girl', 'had', 'been', 'a', 'dead', '.', 'He', 'felt', 'the', 'children', 'for', 'his', 'figures', 'away', 'from', 'him', ',', 'without', 'the', 'need', 'of', 'her', 'feelings', 'there', 'had', 'been', 'at', 'work', ',', 'but', 'he', 'felt', 'a', 'profound', 'conviction', 'that', 'it', 'would', 'be', 'his', 'own', '.', 'Comrade', 'Ogilvy', ',', 'unimagined', 'an', 'hour', 'ago', ',', 'was', 'now', 'a', 'fact', '.', 'It', 'struck', 'him', 'as', 'curious', 'that', 'you', 'could', 'create', 'dead', 'men', 'but', 'not', 'living', 'ones', '.', 'Comrade', 'Ogilvy', ',', 'who', 'had', 'never', 'existed', 'in', 'the', 'present', ',', 'now', 'existed', 'in', 'the', 'past', ',', 'and', 'when', 'once', 'the', 'act', 'of', 'forgery', 'was', 'forgotten', ',', 'he', 'would', 'exist', 'just', 'as', 'authentically', ',', 'and', 'upon', 'the', 'same', 'evidence', ',', 'as', 'Charlemagne', 'or', 'Julius', 'Caesar', '.', 'Chapter', '5', 'In', 'the', 'low', '-', 'ceilinged', 'canteen', ',', 'deep', 'underground', ',', 'the', 'lunch', 'queue', 'jerked', 'slowly', 'forward', '.', 'The', 'room', 'was', 'already', 'very', 'full', 'and', 'deafeningly', 'noisy', '.', 'From', 'the', 'grille', 'at', 'the', 'counter', 'the', 'steam', 'of', 'stew', 'came', 'pouring', 'forth', ',', 'with', 'a', 'sour', 'metallic', 'smell', 'which']
# Epoch 1, Train Loss 23.68897045403719
# Epoch 2, Train Loss 21.078145215287805
# Epoch 3, Train Loss 18.112709091044962
# Epoch 4, Train Loss 24.59329507406801
# Epoch 5, Train Loss 20.050250636413693
# Epoch 6, Train Loss 24.94952774979174
# Epoch 7, Train Loss 24.129000117070973
# Epoch 8, Train Loss 19.249644513241947
# Epoch 9, Train Loss 25.819933014921844
# Epoch 10, Train Loss 22.18262093886733
# ['None', 'into', 'two', 'minutes', 'which', 'they', 'pushed', 'in', 'the', 'corridor', '.', 'It', 'was', 'not', 'required', 'that', 'they', 'were', 'a', 'good', '-', 'lunged', 'metallic', 'political', 'object', '.', 'It', 'was', 'like', 'almost', 'at', 'the', 'moment', 'he', 'had', 'a', 'strange', 'that', 'had', 'happened', 'this', 'people', ';', 'and', 'in', 'such', 'as', 'others', ';', 'but', 'it', 'was', 'never', 'necessary', 'to', 'remain', 'sure', ',', 'but', 'his', 'eyes', 'have', 'been', 'been', 'at', 'any', 'other', 'way', ',', 'we', 'are', 'ready', 'to', 'remember', 'what', 'the', 'word', 'actual', 'feelings', ',', 'their', 'tune', 'while', 'all', 'the', 'In', 'the', 'world', ',', 'hundreds', 'and', 'its', ',', 'fact', 'can', 'instinct', 'through', 'the', 'Revolution', '.', 'But', 'it', 'was', 'only', 'by', 'unconsciousness', ',', 'and', 'recognized', '.', "'", 'How', 'are', 'I', 'think', 'not', 'tell', 'the', 'feeling', 'of', 'quivering', 'and', 'the', 'Ministry', 'of', 'St', 'Clement', "'", 's', '!', "'", 'said', 'Winston', '.', "'", 'The', "'", 'thing', 'is', 'the', 'Inner', 'Party', '.', 'In', 'a', 'game', 'of', 'games', '.', 'Winston', 'was', 'in', 'fact', 'you', 'now', '?', "'", "'", 'And', 'then', 'me', 'for', 'stop', '?', "'", "'", 'How', 'have', 'do', 'her', '?', "'", 'said', 'Julia', '.', "'", 'I', 'am', 'like', '.', "'", "'", 'You', 'are', 'very', 'alive', 'to', 'nothing', 'a', 'few', 'days', 'while', 'they', 'had', 'been', 'sixteen', ',', 'and', 'could', 'be', 'assembled']
# Epoch 1, Train Loss 16.585913663730025
# Epoch 2, Train Loss 16.26362768933177
# Epoch 3, Train Loss 18.210344161838293
# Epoch 4, Train Loss 16.97334594698623
# Epoch 5, Train Loss 24.57536711078137
# Epoch 6, Train Loss 17.5827649673447
# Epoch 7, Train Loss 25.700992468744516
# Epoch 8, Train Loss 23.96403919439763
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 16
#      14         if i % 10 == 0:
#      15             model.store_model(f'epoch_{i + 1}')
# ---> 16 train()
#
# Cell In[21], line 11, in train()
#       8 model.create_model()
#      10 for i in range(100000):
# ---> 11     model.train_model(epochs=10)
#      12     print(model.predict(['None']))
#      14     if i % 10 == 0:
#
# Cell In[20], line 94, in WordLanguageModelWrapper.train_model(self, epochs, lr, skip_factor)
#      91     loss.backward()
#      92     optimizer.step()
# ---> 94     total_loss += loss.item()
#      96     offset += self.context_window * skip_factor
#      97 print(f'Epoch {epoch + 1}, Train Loss {total_loss}')
#
# KeyboardInterrupt:

# %%
model = WordLanguageModelWrapper(hidden_state_dim=512)
model.load_word_embeddings()
model.load_model('epoch_91')
print(model.predict(['Patrik']))
# Out:
# Has CUDA True
# /tmp/ipykernel_124095/2117716861.py:108: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   prediction = self.model.forward(torch.FloatTensor(text_in_tensor).to(self.device))
# ['Patrik', 'scorn', 'allowed', 'the', 'eyes', '.', 'New', 'actresses', 'addressed', 'the', 'enemies', 'pay', 'series', 'ft', 'year', 'for', 'the', 'city', '.', '=', '=', '=', '120', 'at', 'Remaining', 'de', '@,@', ')', '=', 'and', 'number', 'game', 'was', '"', 'Lindisfarne', 'hours', '<unk>', '89', ',', '1947', '@-@', "'s", 'decision', ',', 'or', 'Tell', 'March', 'Francisco', 'Club', 'weapons', 'had', 'allied', '.', 'In', 'a', 'Time', 'and', 'court', 'throw', 'the', '2015', 'Convoy', '(', 'Queensland', 'published', '<unk>', 'rail', '110', 'caused', 'he', 'came', 'greatly', 'got', 'shot', '.', 'An', 'May', 'Cowell', 'was', 'fire', 'economy', '.', 'many', 'was', 'about', 'his', 'other', 'National', 'key', 'storyline', '"', ',', 'with', 'birth', 'greater', 'way', 'to', 'Andrew', 'favored', 'him', 'in', '2008', 'home', ',', 'Aquitaine', 'under', 'them', ',', 'the', '4', 'clubs', '@-@', 'such', 'in', 'the', 'Official', 'teaching', 'jurisdiction', ',', 'as', 'they', 'as', 'the', 'way', 'of', 'the', 'band', ':', 'but', 'supplied', '.', 'He', 'has', 'other', 'firms', 'they', 'eventually', 'trumpets', '.', 'In', 'the', 'inventive', 'dwell', ',', 'the', 'show', 'banned', 'a', '69', 'mph', 'm3', ',', '102', '(', '5', 'League', '6', ')', "'s", 'selection', 'battalion', 'stages', 'of', 'NBC', 'because', 'a', 'MTV', 'mines', 'or', 'central', 'damp', 'Journal', 'and', 'and', 'him', 'or', 'actually', 'helped', 'represented', 'on', 'the', 'Civil', 'interview', 'on', 'this', 'time', ',', 'except', 'the', 'high', 'art', 'with', 'pressure', 'to', 'the', 'reaction', '.', 'Unlike', 'the', 'anti', 'mad']
